# %%
x = 1
y = 0

# %%
try: 
    result = x/y
except ZeroDivisionError as e:
    result = None
    print("error:",e)
    print("cannot be divided by 0. The result will be None.")
print("result:", result)
# Out:
# error: division by zero
# cannot be divided by 0. The result will be None.
# result: None

# %%
try: 
    result = x/z
except ZeroDivisionError as e:
    result = None
    print("error:",e)
    print("cannot be divided by 0. The result will be None.")
except NameError as e:
    print("error:", e)
    print("variable is not defined.The result will be None")
print ("result:", result)
# Out:
# error: name 'z' is not defined
# variable is not defined.The result will be None
# result: None

# %%
z = 3
try: 
    result = x/z
except ZeroDivisionError as e:
    result = None
    print("error:",e)
    print("cannot be divided by 0. The result will be None.")
except NameError as e:
    print("error:", e)
    print("variable is not defined.The result will be None")
else:
    print("there is no error. Will show the result")
print ("result:", result)
# Out:
# there is no error. Will show the result
# result: 0.3333333333333333

# %%
z = 0
try: 
    result = x/z
except ZeroDivisionError as e:
    result = None
    print("error:",e)
    print("cannot be divided by 0. The result will be None.")
except NameError as e:
    print("error:", e)
    print("variable is not defined.The result will be None")
else:
    print("there is no error. Will show the result")
finally:
    print("calculation is completed")

print ("result:", result)
# Out:
# error: division by zero
# cannot be divided by 0. The result will be None.
# calculation is completed
# result: None

# %% [markdown]
# ## Well used error-handling in Web scrappping

# %%
import requests

# %% [markdown]
# ## Error handling

# %%
import requests
url = "https://www.musashino-u.ac.jp/invalid-page"

try:
    response = requests.get(url)
    response.raise_for_status()
except requests.exceptions.HTTPError as e:
    print("HTTPerror:",e)
except requests.exceptions.RequestException as e:
    print("requestError")
else:
    print("got access to Web")
finally:
    print("Web scrapping is done")
# Out:
# HTTPerror: 404 Client Error: Not Found for url: https://www.musashino-u.ac.jp/invalid-page
# Web scrapping is done
